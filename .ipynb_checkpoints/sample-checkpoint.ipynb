# %%
import pandas as pd

busan_road = pd.read_csv("busan_road.csv", encoding="cp949")
busan_road

busan_accident = pd.read_csv("busan_accident.csv", encoding="cp949")
busan_accident

inchun_accident = pd.read_csv("inchun_accident.csv", encoding="cp949")
inchun_accident

inchun_road = pd.read_csv("inchun_road.csv", encoding="cp949")
inchun_road
# Out:
#       번호      도로명(노선수) 폭원(미터)  연장(미터)  면적(제곱미터)       기  점        종  점  \
# 0      1     가람로(검단산단)     25     542     13550   오류동 1434       서측구역계
# 1      2      가석로156번길     21     530     11130  고속도로측도교차점    건지로348번길
# 2      3      가정로151번길     25     365      9125     염곡로교차점      가정로교차점
# 3      4      가정로152번길     25     330      8250     가정로교차점   고속도로측도교차점
# 4      5       가정로98번길     25     320      8000     가정로교차점   고속도로측도교차점
# ..   ...           ...    ...     ...       ...        ...         ...
# 192  193       대 2-116     30     602     18060     대 2-40      대 1-17
# 193  194  중1-176(정서진로)   23.4   14294    334480     서구 시천동  계양구 평동 1-1
# 194  195       대 3-102     25     338      8450      광 3-6     중 2-600
# 195  196       대 3-103     25     213      5325      광 3-6     중 2-600
# 196  197         대1-16     35    1528     53480       광2-4      대3-292
#
#                비 고
# 0           대3-114
# 1              NaN
# 2              NaN
# 3           중1-174
# ...
